# %% [markdown]
# <a href="https://colab.research.google.com/github/amonguscline/ML-Data-analysis/blob/main/projects/Analyzing_California_Housing_Prices.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
houses = pd.read_csv("./sample_data/california_housing_test.csv")
y=houses["median_house_value"] #defining x and y for ML
X=houses.iloc[:,0:-1]
houses
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# ...

# %%
houses["median_house_value"].describe()
# Out:
# count      3000.00000
# mean     205846.27500
# std      113119.68747
# min       22500.00000
# 25%      121200.00000
# 50%      177650.00000
# 75%      263975.00000
# max      500001.00000
# Name: median_house_value, dtype: float64

# %% [markdown]
# you can change the bin size if you want

# %%
filteredhouses = houses[(houses['median_house_value']<500001)]

# %%
plt.hist(data=filteredhouses, x='median_house_value', bins=100, alpha=.7)
plt.xlabel('median house price')
plt.show()

# %% [markdown]
# don't look at the following code first, try to guess what the map means without legend

# %%
plt.figure(figsize=(5,7), dpi=150)
graph = sns.scatterplot(data=houses, x="longitude", y="latitude", hue="median_house_value", palette="Blues", size='total_rooms', sizes=(10,200))
graph.get_legend().remove()
